# %% [markdown]
# # Notebook para Reclutamiento AI
# Este notebook contiene ejemplos para realizar peticiones API, extraer datos de JSON, leer PDFs de CVs e integrarse con ChatGPT usando LangChain.

# %% [markdown]
# ## 1. Importaciones Iniciales

# %%
import requests
import json
import io
from pypdf import PdfReader
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os

# %% [markdown]
# ## 2. Peticiones API Básicas (Ejemplos)

# %%
# GET con expansión de procesos
FUTURE_KEY = ''
# Agregamos "processes" al expand
url_get = f'https://www.getonbrd.com/api/v0/jobs?per_page=10&page=1&api_key={FUTURE_KEY}&expand=["questions"]'
response_get = requests.get(url_get)
if response_get.status_code == 200: 
    print(f"Status: {response_get.status_code}")
    jobs_data = response_get.json()
# Out:
# Status: 200

# %%
# Obtenemos el ID del último trabajo
ultimo_job_id = jobs_data['data'][-1]['id']
print(f"Buscando procesos para el Job: {ultimo_job_id}")
# Out:
# Buscando procesos para el Job: front-end-developer-neuralworks-santiago-e569

# %%
# Petición para obtener los procesos de este trabajo
url_processes = f'https://www.getonbrd.com/api/v0/jobs/{ultimo_job_id}/processes?api_key={API_KEY}'

response_proc = requests.get(url_processes)
if response_proc.status_code == 200:
    processes_data = response_proc.json()
    # Normalmente hay un solo proceso principal, tomamos el ID del primero
    ultimo_process_id = processes_data['data'][0]['id']
    print(f"Process ID encontrado: {ultimo_process_id}")
else:
    print(f"Error obteniendo procesos: {response_proc.status_code}")
    print(response_proc.text)
# Out:
# Process ID encontrado: 51490

# %%
# Ahora pedimos las aplicaciones usando el process_id
url_get_app = f'https://www.getonbrd.com/api/v0/applications?process_id={ultimo_process_id}&per_page=50&page=1&api_key={API_KEY}&expand=["job","phase","professional","answers","notes","messages"]'

response_get_app = requests.get(url_get_app)
if response_get_app.status_code == 200:
    applications_data = response_get_app.json()
    print(f"Se encontraron {len(applications_data['data'])} aplicaciones.")
else:
    print(f"Error en aplicaciones: {response_get_app.status_code}")
# Out:
# Se encontraron 50 aplicaciones.

# %% [markdown]
# ## 3. Extracción de Nombre y CV Link desde JSON

# %%
postulantes = []
for app in applications_data['data']:
    attrs = app.get('attributes', {})
    prof_attrs = attrs.get('professional', {}).get('data', {}).get('attributes', {})
    nombre = prof_attrs.get('name')
    cv_info = prof_attrs.get('uploaded_cv')
    if cv_info and cv_info.get('url'):
        postulantes.append({'nombre': nombre, 'cv_link': cv_info.get('url')})

for p in postulantes: print(f'Nombre: {p["nombre"]} | CV: {p["cv_link"]}')
# Out:
# Nombre: Paloma Cabrillana | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/ea07c38c0f68a947dfb1ce71b6cad96f/paloma_cabrillana_cv%282%29.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=55eaf3b86cafa7648f4ff9944eb82ae3eec938e8b157f0e86e7bab47a0393d42
# Nombre: Cecilia Pilar | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/7c3d99092a8911b34608ff0b0b3f2447/Cecilia_Pilar_CV.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=b09c9d35f62db2f28f0b7a23dbaf55a7bc75e30b0721cc9b1bbc8c699bf5ac49
# Nombre: Claudio Andres Ulloa Castro | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/02aaba8dd5f4e88f53e055d6532a0ed4/Curriculum_Vitae_Claudio_Ulloa.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=971e31807def9ac015c9b0ae6426c64b1807d471f9d94ff8b038ae901dbdfc20
# Nombre: Nicolas Garcia | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/a39a5a3c773c2217fac971e65ee97278/CV_-_Nicolas_Garcia_Rios_EN.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=2cc3a9569e3aa61f8de1c590635c2f29782b7ac8d95610b336fe91a617fa8c11
# Nombre: Sofía Lagos Césped | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/6fc38b2634283b5cd626b2b2e5d21f10/Sof%C3%ADa_Lagos_CV_2025.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=c3a906d6bf5ab3ecb2aec97908ca94520d8fa3aeb624c8f304dd585832486123
# Nombre: Vicente Brevis | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/d3c4c05f14268ab9f19145b4a99df757/CV_VicenteBrevis_2025.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=1eed9a261939a1457bb98f8dcf89045dfaf5c1fb34ae48beb1ab53fa501ecc13
# Nombre: Pablo Abarca | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/01773985db22c273610c2c18abe13e84/PabloAbarca-CV.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=92be3d23e4eab4b8e0e621484904835d431ee9d1108d31f67678e5db23f1ed1a
# Nombre: Felipe Muñoz Guerra | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/70d5834eb23453a58247fe2e88f9a456/CV%282%29.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=0faf3b2d37ac08823f417949c2c83f055b1255512a048107cf00e4f62efdbb60
# Nombre: miussette alfaro silva | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/3530fb761aeaa50257eb45f7aa387ef3/Miussette_Alfaro_CV_act.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=db362f159ef8a8a539e08ba78c8e29890b8f016a64a268e98d2614a3c8195377
# Nombre: Rafú Quichiz Grados | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/fe7f30dd703bf67264e8b3e0bd8325ce/Curr%C3%ADculum_CV_RafuQuichiz.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=539102a30ad4e0135daca93d13a63258804666ad55120525a584e394e5cc3f5a
# Nombre: Maibeet Torres | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/b3b43f5e5cc0b7571e43b8b952cdda9c/cv_maibeet_torres.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=645e4622d255b2838b909d73c0f372540450ef018ec5ec43743417df3c274f59
# Nombre: Deanny Carolina Bruces Molina | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/cb3413b6964df3f9fe3bad3ce9d7336b/CV_Deanny_Bruces_Tech%282%29.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=da0a594f9b90c2a15f6612f85fb7512c334d9d91f0adcde37cf257579ea5ef38
# Nombre: Claudia Pérez Velázquez | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/233c35f6f2e751eae96e7bfcde974dfc/CV_H_Claudia_Perez.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=3f614086218850b980be936c8d898598fdd4eda80132450e75d934f0d4a03fe1
# Nombre: Brian Malave | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/d219eed8a689db3ead628a823169406d/CV_Brian_Malav%C3%A9_-_Espanol_-2025.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=fa9b53a1807058d836cef1e3a1c7ce673b3838f48e8fe82ba545be5eb3eb5512
# Nombre: Benjamin rios reyes | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/fdccb87cdaaa7c0462a68caa3cbf96a0/2024.10-BENJAMIN-R%C3%8DOS-CV.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=e6c5b26644e8d40ca9a1d193cb20d039b0104eae4138ae90e10491bfd16e65bb
# Nombre: Lautaro Olivera | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/ac5f66e443e14fd8bd0c4bcfb5a252d5/olivera-lautaro-cv-EN.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=907f99995fdfc9ccd2055a366adcd18d2ad0f84a08cecb814011cb4a25917966
# Nombre: Viviana Fajardo | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/25af2e46f62c9e4eae5a6d2da74af784/Resume_-_Viviana_Fajardo.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=344da3d508aa54f1022aa60cda7932578fb69c0f477de48b8b274abf0ccff6e7
# Nombre: cristopher Barrientos Matamala | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/a66989a05cd087b7ade008560e43113c/CV-Cristopher_Barrientos.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=0dae70d368a5495b0f2ee3ff5c6443503f47d590a421459d6173eb0271a01d53
# Nombre: Cristian Nieto Albayay | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/222362e52036e189c5bde70e1672358b/CV_Cristian_Nieto_2025.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=8a72279920c24b6db61f40824dcfb17d7b5d98e1cb88bde2393031700fa953b0
# Nombre: Felipe Martínez | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/e0bf1276c107d721d0343d7b58858e9f/Felipe_Martinez_CV.docx?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=6b7441d8a2ef2e4219076f7998d8658cd1cbe31f10fa9bc31c14da21f3841196
# Nombre: Julio Andres Ramírez De Freitas | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/1768c136aaa6fb9df0435f2386b98ec3/Julio-Ramirez-CV-ES.docx.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=bd02e63c965dda63dfedf06e615f6872f73104bc9f9b23a9ebd2bd35c5ec5531
# Nombre: Ángel Smith L | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/4d04db5f396150374e39453265eb36a6/Cv_AngelSmithlgs.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=7d3a7744aeb388c4ec17758a4bff372a0e34743ea6eedf0a3fa1a8c5fa9e8681
# Nombre: ARIEL RUBILAR ALVAREZ | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/f07e5a73bd46c13db90b65ce7c136ea8/CV_Ariel_Rubilar.docx.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=566ff64228d45b43b7610a613d6394ec676bf781f9573e59f7d10f5d510ddc31
# Nombre: Ignacio Arriagada Iriarte | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/fcd5c034c326690dbd600e0c457f2dc4/cv_iarriagada.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=7f254ccf432b9cee3c8e2fb1eb91753781f796c556fecb5a6ff8f0cce50d1a43
# Nombre: Ángel Sandoval | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/8918695ef1d4fade54d61fb8e598776d/cv_Angel_Sandoval_.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=3ff13c521f01f21172f3aac04a096bd4b343934e5099157fa7830b34709ef751
# Nombre: Luis Faúndez Saldivia | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/0a00327a3e16a84e62161d20a6c48ef8/CV_Luis_Fa%C3%BAndez_2025__1_-2.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=4fbf6356ac93e4006c13523b044652ea97fba875598b7488b76d90d72a96f346
# Nombre: Mauricio Vargas | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/e7117ca889a7adcdd20d7d4dadee1d20/Mauricio_Vargas_cv-2025.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=6ada3024db62c825e979950af32b26ca224a19cb06da58577b6f76994ae47929
# Nombre: Marcos Contreras | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/28c4fa380cbb66ca16692a9a9950df6b/bumeran_1000951198_514983875490346260.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=6a51acfb3a3d5905ac6e96045019a6156f91808691a16af93df24771c95861a6
# Nombre: Eduardo Manzanares | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/b9bb0867e189aed357f83de9003790c7/Eduardo_Manzanares_Frontend_UI_Designer.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=b4f651b0f19a2c86e7302637810b3002ef8dead20c5b5d96d44a1b99876169a6
# Nombre: Jorge Arancibia Leiva | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/26c4a95d180cdabb47f14f28fe104483/CV_Jorge_Arancibia.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=41919eb61b0a0d687d05262f93c42c9bbb9d00955c98aff5a9d9009d95353414
# Nombre: Beatriz Eugenia Ortega Rengifo | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/1f3f5b5b31cc34c2da74967c5013a643/CV_Beatriz_Ortega.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=04b133ce3a0cd087100f6bdd34542c9f7158ca7394990b846c2927df749de038
# Nombre: Sebastián Meneses Núñez | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/4d2b70129aecff9a69fa1a9f4f56e399/RESUME_2025.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=0727a84c71fa453a48eb4e74000d48347f77eb3a3cdf874fdb91ae26ce0409a9
# Nombre: Sebastian Johnson | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/580c200b2b781364c7f69b109190f121/CV_Sebastian_Johnson__ES-EN_.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=7983e9a9768d9a2430eed849eb79857a2bccde210e4d81c040130f5f78655112
# Nombre: Ruben Peña Parada | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/8f4718ffffe2858e47f93f64bddacdaa/CV_Ruben_Pen%CC%83a_21537288K_E.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=b9a0c631dc6258ad6b0e4ef537ac406ac9d66ec2202006f340f3b182a28d4b61
# Nombre: Rene Castañeda Tobar | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/82e494cc600894a7b868773f9f1efe7e/CV_Rene_Castaneda_Tobar.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=129f1832d87247a5ab8fb673d8a9120446cfa23777be7ce99411feb74a46ee74
# Nombre: Enrique Fuenzalida | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/a0b3b59afcd8af2ba4f3d6c15a468115/CV_FEB2025_.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=6f26e48a8d1c34c14563c899d7a2512da17e7b17da4f62020582c71fae4be8de
# Nombre: Federico Huneeus García | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/012c9fba3e7097fb4dcace3a0751c2e5/Resume_Federico_Huneeus__5___1_.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=ee57c5f959b3dcd096d82b2c742c6c7adda338a2525fea4c67bc4121fda8b3a1
# Nombre: Miguel Contreras Caro | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/362d28b0da97863b82c7d5ae7b1e2eb5/CV_MIGUEL_CONTRERAS.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=5ada0f02b387089554e8c3d8899a1d55ce0524774f40fad680ae1b8332d83364
# Nombre: Sol Ninoska | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/9bc5c242e7eb1bd3454af13b41ebf706/cv-solNins%282%29.briceno.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=efdf92cf4d821342e1f66df48a263024311f56c560db3c52f17b23ca3237306c
# Nombre: Paola González Guzmán | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/616b267d4c90ac535494fdf1cca43137/Paola_Gonza%CC%81lez_CV%282%29.docx.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=8e1bbf1d1124ebcb1c86b8c8aa04aee41644c48f6c580f9d49558563e55b2c33
# Nombre: Raúl Opazo Muñoz | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/7f87097aa987cce49ac57d68df05181e/CV_Raul_Opazo%282%29.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=cc71f9a83c2889413e8614322ed8064a8224f40a3794a972f80bf83c31741619
# Nombre: Jaicker Rafael Lozano Flores | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/4f28d7db54c8f2732c2c18f3cf86f3dd/CV_Jaicker_Lozano_actualizado.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=ae83bddfb1202c15c242222cf1da0cad39e8a641b639e454473c852f8238a72c
# Nombre: Marcos Flores | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/3df7ea15512c531ada06f8fd52d79a91/Resume_En_MarcosFlores.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=f60ad62bc60599362a0677a239b7b03f5a3138d892b3413e5c51f797c915c6bc
# Nombre: Cristobal Andrade | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/fd8e7977c981c9a8a153558648f1e146/Curriculum_Cristobal_Jose_Andrade_Steil.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=fa027fcc742959b5730f15da712fb0c241bd90d55b65a16af59acf11e5590d43
# Nombre: Carla J Matus | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/9d8dcadeb72d14b1a41ad0d15cbfc91d/CV-CarlaJM%282%29.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=5cb28680a9dfb41445ff3f13f048f128fbc0ac762dc7b116b260056771444fbd
# Nombre: Antonia Reyes | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/443488f0f9993f037a482f41b6e32f33/CV_Antonia_Reyes.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=38b286f14ca2e7141e296fa7b1fc5cabb75587ddf8f4cb8953650850e69268f2
# Nombre: Camila Flores Ferreira | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/5cc30934d2c61482f48d935e6534db17/camila_flores_cv.docx?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=5df4889fc812fe8fea0e9806821e3467c838d65ab1b3fc3aad43d379ed7d399e
# Nombre: Manuel Michelangelli | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/21acbec7d517d6f538ace4b59d935f19/nuevo-cv.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=04ad3bd5fe1780f60c6343307520060277a068054efe4a920fc7427ac00a460c
# Nombre: Anderson Núñez | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/6086e2ee26e80940553c43261409b671/Anderson_CV__1_.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=dcc34acc5ef0343069cbb928f4864a831a69ff769b69614630462f766d8f68c1
# Nombre: Emilio Andrich Guevara | CV: https://getonbrd-prod.s3.amazonaws.com/uploads/cv/f28b8bffc09684c64a0c6586b4d59d47/Document__2_.pdf?X-Amz-Expires=86400&X-Amz-Date=20260112T211036Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJT5MYUSOEN4SITVA%2F20260112%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=2ac0845b8e70fee3f10d598721706fa955f8d8a6186cd635a7f29ebcbd0f34a9

# %% [markdown]
# ## 4. Función para extraer texto de PDF

# %%
def extract_text_from_pdf_url(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            # Verificar si el contenido empieza con la firma de PDF (%PDF)
            if not response.content.startswith(b"%PDF"):
                return "Error: El link expiró o el contenido no es un PDF válido (posible Access Denied de S3)."
            
            with io.BytesIO(response.content) as f:
                reader = PdfReader(f)
                text = ""
                for page in reader.pages:
                    text += page.extract_text() + "\n"
                return text.strip()
        else:
            return f"Error al descargar: {response.status_code}"
    except Exception as e:
        return f"Error procesando PDF: {str(e)}"

pdf_to_text_list = {}
for p in postulantes:
    print(f'Extracting text from {p["nombre"]} CV...')
    text = extract_text_from_pdf_url(p['cv_link'])
    pdf_to_text_list[p['nombre']] = text
# Out:
# Extracting text from Paloma Cabrillana CV...
# Extracting text from Cecilia Pilar CV...
# Extracting text from Claudio Andres Ulloa Castro CV...
# Extracting text from Nicolas Garcia CV...
# Ignoring wrong pointing object 86 0 (offset 0)
# Extracting text from Sofía Lagos Césped CV...
# Extracting text from Vicente Brevis CV...
# Extracting text from Pablo Abarca CV...
# Ignoring wrong pointing object 141 0 (offset 0)
# Extracting text from Felipe Muñoz Guerra CV...
# Extracting text from miussette alfaro silva CV...
# Extracting text from Rafú Quichiz Grados CV...
# Extracting text from Maibeet Torres CV...
# Extracting text from Deanny Carolina Bruces Molina CV...
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)
# Extracting text from Claudia Pérez Velázquez CV...
# Extracting text from Brian Malave CV...
# Extracting text from Benjamin rios reyes CV...
# Extracting text from Lautaro Olivera CV...
# Extracting text from Viviana Fajardo CV...
# Extracting text from cristopher Barrientos Matamala CV...
# Extracting text from Cristian Nieto Albayay CV...
# Extracting text from Felipe Martínez CV...
# Extracting text from Julio Andres Ramírez De Freitas CV...
# Extracting text from Ángel Smith L CV...
# Extracting text from ARIEL RUBILAR ALVAREZ CV...
# Extracting text from Ignacio Arriagada Iriarte CV...
# Extracting text from Ángel Sandoval CV...
# Extracting text from Luis Faúndez Saldivia CV...
# Extracting text from Mauricio Vargas CV...
# Extracting text from Marcos Contreras CV...
# Extracting text from Eduardo Manzanares CV...
# Extracting text from Jorge Arancibia Leiva CV...
# Extracting text from Beatriz Eugenia Ortega Rengifo CV...
# Extracting text from Sebastián Meneses Núñez CV...
# Extracting text from Sebastian Johnson CV...
# Extracting text from Ruben Peña Parada CV...
# Extracting text from Rene Castañeda Tobar CV...
# Extracting text from Enrique Fuenzalida CV...
# Ignoring wrong pointing object 11 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Extracting text from Federico Huneeus García CV...
# Extracting text from Miguel Contreras Caro CV...
# Extracting text from Sol Ninoska CV...
# Extracting text from Paola González Guzmán CV...
# Extracting text from Raúl Opazo Muñoz CV...
# Extracting text from Jaicker Rafael Lozano Flores CV...
# Extracting text from Marcos Flores CV...
# Extracting text from Cristobal Andrade CV...
# Extracting text from Carla J Matus CV...
# Extracting text from Antonia Reyes CV...
# Extracting text from Camila Flores Ferreira CV...
# Extracting text from Manuel Michelangelli CV...
# Extracting text from Anderson Núñez CV...
# Extracting text from Emilio Andrich Guevara CV...

# %% [markdown]
# ## 5. Integración LangChain + ChatGPT

# %%
# Buscamos el trabajo que coincida con el ID
job_attributes = None
for job in jobs_data['data']:
    if job.get('id') == ultimo_job_id:
        job_attributes = job.get('attributes')
        break

# %%
texto_cv = pdf_to_text_list[list(pdf_to_text_list.keys())[20]]

# Define tu API Key aquí
OPENAI_APIKEY = ""

# Configurar el modelo con la llave directa
llm = ChatOpenAI(
    model='gpt-4o-mini', 
    temperature=0,
    api_key=OPENAI_APIKEY  # Se pasa directamente aquí
)


system_prompt = """
Eres un asistente de reclutamiento que evalúa la compatibilidad entre una descripción de cargo y un CV. Eres el encargado de evaluar el CV de un postulante para un cargo en particular, y decidir si es aceptado o rechazado para la entrevista inicial.

INSTRUCCIONES IMPORTANTES
- Usa SOLO la información proporcionada en JOB_DESCRIPTION y CV. No inventes nada.
- Si falta información crítica para evaluar un requisito, márcalo como "no evidenciado" (no asumas).
- No uses ni infieras atributos sensibles (edad, género, raza, nacionalidad, religión, estado civil, salud, etc.) para decidir.
- No penalices por redacción, formato, ortografía o largo del CV.
- Si el CV contiene HTML o listas, interprétalo como texto.
- El postulante debe haber estudiado en las universidades más reconocidas de Chile.

OBJETIVO
Dado un JOB_DESCRIPTION y un CV, debes:
1) Determinar DECISION: "accept" o "reject"
2) Entregar SCORE entero de 1 a 5 (5 = muy buen match)
3) Entregar JUSTIFICACION breve y específica, basada en evidencia del CV

ESCALA DE SCORE (OBLIGATORIA)
- 5: Cumple claramente la mayoría de requisitos clave + evidencia fuerte + experiencia muy alineada.
- 4: Cumple muchos requisitos clave + pocos gaps menores.
- 3: Cumple algunos requisitos clave, pero faltan varios requisitos importantes o evidencia incompleta.
- 2: Cumple pocos requisitos clave, desalineación relevante.
- 1: No cumple requisitos clave o no hay evidencia suficiente.

REGLA DE DECISIÓN (OBLIGATORIA)
- "accept" si SCORE >= 4
- "reject" si SCORE <= 3
(Si estás indeciso, usa 3 y reject; explica qué faltó.)

FORMATO DE RESPUESTA (OBLIGATORIO)
Responde SOLO con un JSON válido, sin texto adicional, con este esquema exacto:

{{
  "decision": "accept|reject",
  "score": 1,
  "justification": "Tu justificación para la decisión",
  "evidence": [
    {{
      "requirement": "requisito del job (corto)",
      "cv_evidence": "cita o fragmento del CV que lo respalda, o 'no evidenciado'",
      "match": "strong|partial|none"
    }}
  ],
  "strengths": ["lista corta (máx 3)"],
  "gaps": ["lista corta (máx 3)"],
  "follow_up_questions": ["máx 3 preguntas para despejar dudas críticas"]
}}

CRITERIOS DE EVALUACIÓN
1) Identifica 5 a 8 requisitos clave del JOB_DESCRIPTION.
2) Busca evidencia en el CV para cada requisito.
3) Da match strong/partial/none por requisito.
4) Calcula SCORE según la escala.
5) Genera DECISION usando la regla.
""".strip()

# ... (el resto del código sigue igual)

prompt_template = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("user", "JOB_DESCRIPTION:\n\n{job_description}\n\nCV:\n\n{texto_cv}")
])

chain = prompt_template | llm

# --- Variables de entrada ---
# job_description: string con la descripción del cargo
# cv: string con el CV (puede incluir HTML)

respuesta = chain.invoke({
    "job_description": str(job_attributes),
    "texto_cv": texto_cv
})

print(respuesta.content)
# Out:
# ```json
# {
#   "decision": "reject",
#   "score": 3,
#   "justification": "El candidato tiene experiencia relevante en desarrollo frontend y habilidades técnicas sólidas, pero no se evidencia que haya estudiado en una universidad reconocida de Chile, y su nivel de inglés no está claro.",
#   "evidence": [
#     {
#       "requirement": "Estudios de Ingeniería Civil en Computación o similar",
#       "cv_evidence": "DUOC UC, Ingeniero de Sistemas",
#       "match": "none"
#     },
#     {
#       "requirement": "Experiencia de al menos 2 años como Frontend Developer",
#       "cv_evidence": "Más de 4 años de experiencia entregando plataformas SaaS, MVPs y aplicaciones intensivas en datos.",
#       "match": "strong"
#     },
#     {
#       "requirement": "Comprensión de las API RESTful",
#       "cv_evidence": "Diseñé y mantuve APIs RESTful con Node.js y MongoDB",
#       "match": "strong"
#     },
#     {
#       "requirement": "Habilidad para trabajar en equipo",
#       "cv_evidence": "Sólido colaborador en equipos multidisciplinarios",
#       "match": "strong"
#     },
#     {
#       "requirement": "Buen manejo comunicacional y skills de colaboración",
#       "cv_evidence": "Colaboré en un entorno ágil con ingenieros backend, diseñadores, investigadores de IA",
#       "match": "strong"
#     },
#     {
#       "requirement": "Buen manejo de inglés",
#       "cv_evidence": "no evidenciado",
#       "match": "none"
#     }
#   ],
#   "strengths": [
#     "Experiencia sólida en desarrollo frontend",
#     "Habilidad para trabajar en equipo",
#     "Comprensión de APIs RESTful"
#   ],
#   "gaps": [
#     "Falta de estudios en una universidad reconocida de Chile",
#     "Nivel de inglés no evidenciado"
#   ],
#   "follow_up_questions": [
#     "¿Cuál es tu nivel de inglés, especialmente en lectura?",
#     "¿Has estudiado en alguna universidad reconocida de Chile?"
#   ]
# }
# ```
